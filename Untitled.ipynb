# %%
import tabula
import pandas as pd
import os
import datetime
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 
import math
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import statsmodels.api as sm
import matplotlib
# pd.options.display.max_rows = 20000
# pd.options.display.max_columns = 10000

# %%
# change campus names
def change_campus(df):
    
    # school name dictionary
    school_dict = {
        'High': '',
        'Elem School': '',
        'Elementary': '',
        'Middle': '',
        'School': '',
        'HS': '',
        'ES': '',
        'MS': '',
        'Tr.': 'Trail',
        '/Regular': '',
        ' - ': ' ',
        'Daep': 'DAEP',
        'Juvenile Ctr': '',
        'Wm.': '',
        'Wm S': '',
        'JJAEP/': '',
        'Xenia': '',
        'Liveoak': 'Live Oak',
        'Linda Herrington': 'Herrington',
        'Elsa ': '',
        'Linda': 'Herrington',
        'C. D. Fulkes': 'C.D. Fulkes',
        'RROC': 'Round Rock Opportunity Center',
        'RRISD ': '',
        'Joe Lee ': '',
        'James Walsh': 'Walsh',
        'Neysa Callison': 'Callison',
        'Kathy Caraway': 'Caraway',
        'Noel Grisham': 'Grisham',
        'Claude Berkman': 'Berkman',
        'Patsy Sommer': 'Sommer',
        '\t\r': '',
        '  ': ' ',
        'Lott': 'LOTT',
        'Elem: DAEP': 'DAEP',
        'Elem: ': '',
    }
    
    # change keys(k) to values(v)
    for k, v in school_dict.items():
        df['Campus'] = df['Campus'].map(lambda dis_cell: dis_cell.replace(k, v).strip())
    
    return None

# %%
school_type = {
    # list of middle schools
    'C.D. Fulkes': 'MS',
    'Canyon Vista': 'MS',
    'Cedar Valley': 'MS',
    'Chisholm Trail': 'MS',
    'Deerpark': 'MS',
    'Grisham': 'MS',
    'Hernandez': 'MS',
    'Hopewell': 'MS',
    'Pearson Ranch': 'MS',
    'Ridgeview': 'MS',
    'Walsh': 'MS',
    
    # list of high schools
    'Cedar Ridge': 'HS',
    'McNeil': 'HS',
    'Round Rock': 'HS',
    'Stony Point': 'HS',
    'Westwood': 'HS',
    'Success': 'HS',
    'Early College': 'HS',
    
    # other schools
    'Round Rock Opportunity Center': 'Other',
    'DAEP': 'Other',
    'JJAEP': 'Other',
    'LOTT': 'Other',
}

# %%
# path for excel files
path = os.getcwd() + '/data/excel/'

# read all pdf files in a directory and convert to pd dataframe
# returns a dataframe
def read_excel_files(path):
    
    # get all filesnames in a given folder
    filenames = os.listdir(path)

    # create an empty dataframe
    df = pd.DataFrame()
    
    # count variable to count the number of files
    count = 0
    
    # for each files in the given directory(path)
    for filename in filenames:
        
        # print a filename
        print(filename)
        
        # get each sheets in an excel file
        sheets = pd.ExcelFile(path + filename).book.sheets()
        
        # for each sheets in a working excel file
        for sheet in sheets:
            
            # check if there is a hidden sheet and its name isn't 'Enrollment Graphs'
            if ((sheet.visibility == 0) & (sheet.name != 'Enrollment Graphs')):
                
                # read each sheet as a panda dataframe
                temp = pd.read_excel(path + filename, header=2, sheet_name=sheet.name)
                
                # convert all column names into lowercase
                temp.columns = [str(x).lower() for x in temp.columns]
                
                # columns of the dataframe from the sheet
                cols = temp.columns
                
                # campus name which is the first column in the dataframe
                campus_colname = cols[0]
                
                # cumulative column name
                cum_colname = [col for col in [str(col).lower() for col in cols] if col.startswith('cum')][0]
                
                # projected column name
                pro_colname= [col for col in [str(col).lower() for col in cols] if 'proj' in col][0]
                
                # select columns we want from the dataframe
                temp = temp[[campus_colname, cum_colname, pro_colname]]
                
                # change column names
                temp.columns = ['Campus', 'Cumulative', 'Projected']
                
                # get date from filenames and convert to datetime object
                temp['Date'] = filename[:10]
                
                # change a filename with '.' instead of '-'
                temp['Date'] = temp['Date'].str.replace(".", "-")
                
                # change Date column into datetime object
                temp['Date'] = pd.to_datetime(temp['Date'])

                # remove unnecessary rows (total, campus - header rows)
                temp = temp[temp['Campus'].str.contains('tota|campus', case=False, regex=True) != True]
                
                # append each temp dataframes(sheets) to df
                df = df.append(temp, sort=False)
        
        # increment the number of files
        count += 1
    
    # print how many files are converted
    print('number of files:', count)
    
    # change ' ' to integer 0 in 'Projected' column
    df['Projected'].loc[df['Projected'] == ' '] = 0

    # drop NaNs
    df = df.dropna()

    # change each columns data types
    df['Cumulative'] = df['Cumulative'].astype(int)
    df['Projected'] = df['Projected'].astype(int)

    # create 'Difference' column
    df['Difference'] = df['Cumulative'] - df['Projected']
    
    # change school names
    change_campus(df)
    
    # sort and reset index
    df.sort_values(by=['Date', 'Campus'], inplace=True)
    df.reset_index(drop=True, inplace=True)
    
    return df

# %%
# save to a variable
excel_df = read_excel_files(path)

# %%
path = os.getcwd() + '/data/pdf/'

def read_pdf_files(path):
    filenames = os.listdir(path)
    pdf_df = pd.DataFrame()
    count = 0
    for filename in filenames:
        if filename.endswith('pdf'):
            print(filename)
            try :
                # read all pages from a pdf
                # pdf returns a list of dataframes
                # one dataframe for each page (pdf[0], pdf[1]...)
                # does not merge files don't have projected numbers
                pdf = tabula.read_pdf(path + filename, pages='all', multiple_tables=True, spreadsheet=True)

                # merge all dataframes into one    
                pdf = pd.concat(pdf, join='inner', axis=0)

                # get columns we want, rename columns
                pdf = pdf[[0, 17, 18]]
                pdf = pdf.rename({0: 'Campus', 17: 'Cumulative', 18: 'Projected'}, axis='columns')

                # remove unnecessary rows (total, campus - header rows)
                pdf = pdf[pdf['Campus'].str.contains('tot|campus', case=False, regex=True) != True]

                # remove rows that cumulative is NaN (like Anderson Mill Non‐LEP DL, Anderson Mill/ESOL)
                pdf = pdf[pdf['Cumulative'].notna()]

                # get dates from a filename
                filename = filename.replace('.pdf', '').strip()
                filename = filename.replace(' -  last day of school', '').strip()
                if len(filename) == 10:
                    filename = datetime.datetime.strptime(filename, '%m-%d-%Y')
                elif len(filename) == 8:
                    filename = datetime.datetime.strptime(filename, '%m-%d-%y')
                pdf['Date'] = filename


                pdf_df = pdf_df.append(pdf)

                count += 1

            except KeyError:
                print(filename, 'Did not merge')

    pdf_df.sort_values(by=['Date', 'Campus'], inplace=True)
    pdf_df.reset_index(drop=True, inplace=True)
    print('number of files:', count)

    print('changing datatypes')
    pdf_df['Cumulative'] = pdf_df['Cumulative'].astype(int)
    pdf_df['Projected'] = pdf_df['Projected'].astype(int)
    pdf_df['Difference'] = pdf_df['Cumulative'] - pdf_df['Projected']
    
    change_campus(pdf_df)
    
    return pdf_df

# %%
pdf_df = read_pdf_files(path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3615472217aa> in <module>
# ----> 1 pdf_df = read_pdf_files(path)
#
# <ipython-input-4-7b8b31c9172a> in read_pdf_files(path)
#       2
#       3 def read_pdf_files(path):
# ----> 4     filenames = os.listdir(path)
#       5     pdf_df = pd.DataFrame()
#       6     count = 0
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/steve/Documents/GA/rrisd/data/pdf/'

# %%
combined['Target'] = combined.groupby("Campus")['Cumulative'].shift(-1)
combined = combined.dropna()
count = 0
for i in set(combined['Campus'].value_counts().index):
    count += 1
    df_school = combined[combined['Campus'] == i]
    df_school = df_school.dropna()
    X = df_school[['Cumulative']]
    y = df_school[['Campus', 'Cumulative', 'Projected', 'Date', 'Difference', 'Target']]
    X_train, X_test, y_train, y_test = train_test_split(X, y)
    lr = LinearRegression()
    lr.fit(X_train, y_train['Target'])
    predictions = lr.predict(X_test)
    y_test['Predicted'] = predictions
#     plt.figure(figsize=(20,5))
#     plt.title(i)
#     plt.scatter(x=df_school['Date'], y=df_school['Projected']);
#     plt.scatter(x=df_school['Date'], y=df_school['Cumulative']);
#     plt.scatter(x=df_school['Date'], y=df_school['Predicted']);
    print(i, count)
    print(lr.score(X_test, y_test['Target']))
    print('-----------------------------------------------------')

# %%
df_datetime = combined
df_datetime['Date'] = pd.to_datetime(df_datetime['Date'])
df_datetime = df_datetime.set_index('Date')

for i in set(df_datetime['Campus'].value_counts().index):
    try:
    #        df_school = df[df['Campus'] == i]
        df_train_school = df_datetime['20120810':'20160610']
        df_test_school = df_datetime['20160701':'20181016']
        df_train_school = df_train_school[df_train_school['Campus'] == i]
        df_test_school = df_test_school[df_test_school['Campus'] == i]
        X_train = df_train_school[['Cumulative']]
        y_train = df_train_school['Target']
        X_test = df_test_school[['Cumulative']]
        y_test = df_test_school['Target']
        lr = LinearRegression()
        lr.fit(X_train, y_train)
        predictions = lr.predict(X_test)
        df_test_school['Predicted'] = predictions
        df_test_school['Pred Diff'] = df_test_school['Predicted'] - df_test_school['Cumulative']

    #    print(df_test_school['Pred Diff'].sum())
    #         y_test['Predicted'] = predictions
    #         plt.figure(figsize=(20,5))
    #         plt.title(i)
    #         plt.scatter(x=df_school['Date'], y=df_school['Projected']);
    #         plt.scatter(x=df_school['Date'], y=df_school['Cumulative']);
    #         plt.scatter(x=y_test['Date'], y=y_test['Predicted']);
        print(i)
        print('RMSE Our Prediction: ' + str(math.sqrt(mean_squared_error(y_test, predictions))))
        print('RMSE RRISD Prediction: ' + str(math.sqrt(mean_squared_error(df_test_school['Cumulative'], df_test_school['Projected']))))
        print(lr.score(X_test, y_test))
        print('-----------------------------------------------------')
    except:
        pass

# %%
# path for files
path = os.getcwd() + '/data/'

def read_files(path):
    '''
    read all files in a directory and convert to pd dataframe
    read files with .xlsx and .pdf
    returns a dataframe
    '''
    # get all filesnames in a given folder
    filenames = os.listdir(path)
    
    # create empty dataframes
    df_excel = pd.DataFrame()
    df_pdf = pd.DataFrame()
    
    # count variable to count the number of files
    count_excel = 0
    count_pdf = 0
    count_err = 0
    
    # for each files in the given directory(path)
    for filename in filenames:
        print(filename)
        
        # if filename ends with 'xlsx'
        if filename.endswith('xlsx'):

            # get each sheets in an excel file
            sheets = pd.ExcelFile(path + filename).book.sheets()

            # for each sheets in a working excel file
            for sheet in sheets:

                # check if there is a hidden sheet and its name isn't 'Enrollment Graphs'
                if ((sheet.visibility == 0) & (sheet.name != 'Enrollment Graphs')):

                    # read each sheet as a panda dataframe
                    temp = pd.read_excel(path + filename, header=2, sheet_name=sheet.name)

                    # convert all column names into lowercase
                    temp.columns = [str(x).lower() for x in temp.columns]

                    # columns of the dataframe from the sheet
                    cols = temp.columns

                    # campus name which is the first column in the dataframe
                    campus_colname = cols[0]

                    # cumulative column name
                    cum_colname = [col for col in [str(col).lower() for col in cols] if col.startswith('cum')][0]

                    # projected column name
                    pro_colname= [col for col in [str(col).lower() for col in cols] if 'proj' in col][0]

                    # select columns we want from the dataframe
                    temp = temp[[campus_colname, cum_colname, pro_colname]]

                    # change column names
                    temp.columns = ['Campus', 'Cumulative', 'Projected']

                    # get date from filenames and convert to datetime object
                    temp['Date'] = filename[:10]

                    # change a filename with '.' instead of '-'
                    temp['Date'] = temp['Date'].str.replace(".", "-")

                    # change Date column into datetime object
                    temp['Date'] = pd.to_datetime(temp['Date'])

                    # remove unnecessary rows (total, campus - header rows)
                    temp = temp[temp['Campus'].str.contains('tota|campus', case=False, regex=True) != True]

                    # append each temp dataframes(sheets) to df
                    df_excel = df_excel.append(temp, sort=False)

            # increment the number of files
            count_excel += 1
        
        elif filename.endswith('pdf'):
            try :
                # read all pages from a pdf
                # pdf returns a list of dataframes
                # one dataframe for each page (pdf[0], pdf[1]...)
                # does not merge files don't have projected numbers
                pdf = tabula.read_pdf(path + filename, pages='all', multiple_tables=True, spreadsheet=True)

                # merge all dataframes into one    
                pdf = pd.concat(pdf, join='inner', axis=0)

                # get columns we want, rename columns
                pdf = pdf[[0, 17, 18]]
                pdf = pdf.rename({0: 'Campus', 17: 'Cumulative', 18: 'Projected'}, axis='columns')

                # remove unnecessary rows (total, campus - header rows)
                pdf = pdf[pdf['Campus'].str.contains('tot|campus', case=False, regex=True) != True]

                # remove rows that cumulative is NaN (like Anderson Mill Non‐LEP DL, Anderson Mill/ESOL)
                pdf = pdf[pdf['Cumulative'].notna()]

                # get dates from a filename
                filename = filename.replace('.pdf', '').strip()
                filename = filename.replace(' -  last day of school', '').strip()
                if len(filename) == 10:
                    filename = datetime.datetime.strptime(filename, '%m-%d-%Y')
                elif len(filename) == 8:
                    filename = datetime.datetime.strptime(filename, '%m-%d-%y')
                pdf['Date'] = filename


                df_pdf = df_pdf.append(pdf)

                count_pdf += 1

            except KeyError:
                print(filename, 'Did not merge')
                count_err += 1

    # print how many files are converted
    print('There is ',len(filenames), 'files total')
    print('number of excel files:', count_excel)
    print('number of pdf files:', count_pdf)
    print(count_err, 'files are not merged')
    print((len(filenames) - count_excel - count_pdf - count_err), 'files are not pdf or xlsx')

    # change ' ' to integer 0 in 'Projected' column
    df_excel['Projected'].loc[df_excel['Projected'] == ' '] = 0
    
    # drop NaNs in excel dataframe
    df_excel = df_excel.dropna()
    
    # change each columns data types
    print('changing datatypes')
    df_excel['Cumulative'] = df_excel['Cumulative'].astype(int)
    df_excel['Projected'] = df_excel['Projected'].astype(int)
    df_pdf['Cumulative'] = df_pdf['Cumulative'].astype(int)
    df_pdf['Projected'] = df_pdf['Projected'].astype(int)
    df_pdf['Difference'] = df_pdf['Cumulative'] - df_pdf['Projected']    

    # create 'Difference' column
    df_excel['Difference'] = df_excel['Cumulative'] - df_excel['Projected']
    
    # merge two dataframes
    print('merging dataframes')
    combined = pd.concat([df_pdf, df_excel], join='outer', axis=0, sort=False)
    combined.reset_index(inplace=True, drop=True)
    
    # sort and reset index
    combined.sort_values(by=['Date', 'Campus'], inplace=True)
    combined.reset_index(drop=True, inplace=True)
    
    # changing school names
    print('school name change')
    change_campus(combined)

    print('changing school types')
    for i in range(len(combined)):
        if combined.loc[i, 'Campus'] in school_type.keys():
            combined.loc[i, 'Type'] = school_type[combined.loc[i, 'Campus']]
        else:
            combined.loc[i, 'Type'] = 'ES'

    return combined

# %%
combined = read_files(path)
# Out:
# 11-04-14.pdf
# 01-08-13.pdf.pdf
# 2017-04-11 enrollment.xls.xlsx
# 03-25-2014.pdf
# 12-11-12.pdf.pdf
# 2017-02-07 enrollment.xls.xlsx
# 02-18-2014.pdf
# 09-22-2015.pdf
# 04-08-2014.pdf
# 09-02-14.pdf
# 09-23-2014.pdf
# 03-24-2015.pdf
# 2018-04-17 enrollment.xls.xlsx
# 11-03-2015.pdf
# 02-26-13.pdf.pdf
# 01-14-2014.pdf
# 2017-09-12 enrollment.xls.xlsx
# 01-21-2014.pdf
# 04-29-2014 .pdf
# 09-29-2015.pdf
# 03-10-2015.pdf
# 2016-10-04 enrollment.xls.xlsx
# 09-16-2014.pdf
# 2016-09-20 enrollment.xls.xlsx
# 2018-05-01 enrollment.xls.xlsx
# 2016-11-08 enrollment.xls.xlsx
# 01-20-2015.pdf
# 2018-09-04 Enrollment Report.xls.xlsx
# .DS_Store
# 10-28-14.pdf
# 04-21-2015.pdf
# 2016-09-27 enrollment.xls.xlsx
# 05-17-2016.pdf
# 02-19-13.pdf.pdf
# 2017-10-31 enrollment.xls.xlsx
# 2017-05-02 enrollment.xls.xlsx
# 11-18-14.pdf
# 2016-10-18 enrollment.xls.xlsx
# 2016-11-15 enrollment.xls.xlsx
# 04-14-2015.pdf
# 2016-12-13 enrollment.xls.xlsx
# 2018-04-10 enrollment.xls.xlsx
# 2018-02-06 enrollment.xls.xlsx
# 09-01-2015.pdf
# 03-01-2016.pdf
# 04-09-13.pdf.pdf
# 10-08-14.pdf
# 2017-10-24 enrollment.xls.xlsx
# 08-26-14.pdf
# 04-12-2016.pdf
# 2018-03-06 enrollment.xls.xlsx
# 13                      Cedar Valley        1250       1241 2012-09-11
# 14                     Chandler Oaks         617        618 2012-09-11
# 15                    Chisholm Trail        1061       1073 2012-09-11
# 16                          Deepwood         409        411 2012-09-11
# 17                          Deerpark         950        990 2012-09-11
# 18                 Double File Trail         681        706 2012-09-11
# 19                              DAEP           2          6 2012-09-11
# 20                           England         513        516 2012-09-11
# 21                        Fern Bluff         761        782 2012-09-11
# 22                      Forest Creek         824        827 2012-09-11
# 23                      Forest North         380        399 2012-09-11
# 24                            Gattis         785        779 2012-09-11
# 25                        Great Oaks         753        819 2012-09-11
# 26                           Grisham         685        671 2012-09-11
# 27                         Hernandez         865        936 2012-09-11
# 28                        Herrington         702        644 2012-09-11
# 29                          Hopewell         870        854 2012-09-11
# ...                              ...         ...        ...        ...
# 10255                          JJAEP          12          6 2018-10-23
# 10256                          Walsh        1347       1389 2018-10-23
# 10257                        Johnson         804        807 2018-10-23
# 10258                     Jollyville         453        440 2018-10-23
# 10259                        Caraway         876        814 2018-10-23
# 10260                Laurel Mountain         731        732 2018-10-23
# 10261                     Herrington        1116       1116 2018-10-23
# 10262                       Live Oak         598        571 2018-10-23
# 10263                         McNeil        2677       2758 2018-10-23
# 10264                       Callison         785        810 2018-10-23
# 10265                        Grisham         641        621 2018-10-23
# 10266                       Old Town         716        715 2018-10-23
# 10267                         Sommer        1257       1289 2018-10-23
# 10268                  Pearson Ranch         881        820 2018-10-23
# 10269                   Pond Springs         593        626 2018-10-23
# 10270                    Purple Sage         489        471 2018-10-23
# 10271                  Early College         288        331 2018-10-23
# 10272                      Ridgeview        1367       1333 2018-10-23
# 10273                      Robertson         438        414 2018-10-23
# 10274                     Round Rock        3504       3515 2018-10-23
# 10275  Round Rock Opportunity Center          62         79 2018-10-23
# 10276                      Spicewood         846        812 2018-10-23
# 10277                    Stony Point        2600       2635 2018-10-23
# 10278                        Success         323        315 2018-10-23
# 10279                      Teravista         878        841 2018-10-23
# 10280                     Union Hill         774        723 2018-10-23
# 10281                   Wells Branch         481        486 2018-10-23
# 10282                       Westwood        2760       2770 2018-10-23
# 10283                           LOTT           6          3 2018-10-23
# 10284                          Voigt         586        498 2018-10-23
#
#        Difference   Type
# 0             -80     ES
# 1             -25     ES
# 2               8     ES
# 3             -79     ES
# 4              -4     ES
# 5              50     MS
# 6              33     ES
# 7             -48     ES
# 8             -67     ES
# 9             -27     ES
# 10             14     MS
# 11            -30     ES
# 12           -100     HS
# 13              9     MS
# 14             -1     ES
# 15            -12     MS
# 16             -2     ES
# 17            -40     MS
# 18            -25     ES
# 19             -4  Other
# 20             -3     ES
# 21            -21     ES
# 22             -3     ES
# 23            -19     ES
# 24              6     ES
# 25            -66     ES
# 26             14     MS
# 27            -71     MS
# 28             58     ES
# 29             16     MS
# ...           ...    ...
# 10255           6  Other
# 10256         -42     MS
# 10257          -3     ES
# 10258          13     ES
# 10259          62     ES
# 10260          -1     ES
# 10261           0     ES
# 10262          27     ES
# 10263         -81     HS
# 10264         -25     ES
# 10265          20     MS
# 10266           1     ES
# 10267         -32     ES
# 10268          61     MS
# 10269         -33     ES
# 10270          18     ES
# 10271         -43     HS
# 10272          34     MS
# 10273          24     ES
# 10274         -11     HS
# 10275         -17  Other
# 10276          34     ES
# 10277         -35     HS
# 10278           8     HS
# 10279          37     ES
# 10280          51     ES
# 10281          -5     ES
# 10282         -10     HS
# 10283           3  Other
# 10284          88     ES
#
# [10285 rows x 6 columns]

# %%
elem_school = combined[combined['Type'] == 'ES']

# %%
elem_school.reset_index(inplace=True, drop=True)

# %%
elem_school
# Out:
#                  Campus  Cumulative  Projected       Date  Difference Type
# 0         Anderson Mill         465        545 2012-09-11         -80   ES
# 1               Berkman         526        551 2012-09-11         -25   ES
# 2     Blackland Prairie         903        895 2012-09-11           8   ES
# 3            Bluebonnet         634        713 2012-09-11         -79   ES
# 4          Brushy Creek         778        782 2012-09-11          -4   ES
# 5          Cactus Ranch         984        951 2012-09-11          33   ES
# 6      Caldwell Heights         598        646 2012-09-11         -48   ES
# 7              Callison         863        930 2012-09-11         -67   ES
# 8          Canyon Creek         437        464 2012-09-11         -27   ES
# 9               Caraway         659        689 2012-09-11         -30   ES
# 10        Chandler Oaks         617        618 2012-09-11          -1   ES
# 11             Deepwood         409        411 2012-09-11          -2   ES
# 12    Double File Trail         681        706 2012-09-11         -25   ES
# 13              England         513        516 2012-09-11          -3   ES
# 14           Fern Bluff         761        782 2012-09-11         -21   ES
# 15         Forest Creek         824        827 2012-09-11          -3   ES
# 16         Forest North         380        399 2012-09-11         -19   ES
# 17               Gattis         785        779 2012-09-11           6   ES
# 18           Great Oaks         753        819 2012-09-11         -66   ES
# 19           Herrington         702        644 2012-09-11          58   ES
# 20           Jollyville         504        550 2012-09-11         -46   ES
# 21      Laurel Mountain         768        727 2012-09-11          41   ES
# 22             Live Oak         562        562 2012-09-11           0   ES
# 23             Old Town         819        834 2012-09-11         -15   ES
# 24         Pond Springs         651        663 2012-09-11         -12   ES
# 25          Purple Sage         347        318 2012-09-11          29   ES
# 26            Robertson         523        563 2012-09-11         -40   ES
# 27               Sommer         813        716 2012-09-11          97   ES
# 28            Spicewood         720        703 2012-09-11          17   ES
# 29            Teravista         757        828 2012-09-11         -71   ES
# ...                 ...         ...        ...        ...         ...  ...
# 6419       Cactus Ranch         963        954 2018-10-23           9   ES
# 6420   Caldwell Heights         806        751 2018-10-23          55   ES
# 6421       Canyon Creek         438        425 2018-10-23          13   ES
# 6422      Chandler Oaks         568        562 2018-10-23           6   ES
# 6423            Berkman         476        474 2018-10-23           2   ES
# 6424           Deepwood         392        322 2018-10-23          70   ES
# 6425  Double File Trail         646        642 2018-10-23           4   ES
# 6426            England        1228       1174 2018-10-23          54   ES
# 6427         Fern Bluff         609        594 2018-10-23          15   ES
# 6428       Forest Creek         842        809 2018-10-23          33   ES
# 6429       Forest North         399        360 2018-10-23          39   ES
# 6430             Gattis         746        735 2018-10-23          11   ES
# 6431         Great Oaks         761        705 2018-10-23          56   ES
# 20343       Westwood        2771       2770 2018-09-25           1   HS
# 30628       Westwood        2771       2770 2018-09-25           1   HS
# 40913       Westwood        2771       2770 2018-09-25           1   HS
# 51198       Westwood        2771       2770 2018-09-25           1   HS
# 61483       Westwood        2771       2770 2018-09-25           1   HS
# 10114       Westwood        2772       2770 2018-10-02           2   HS
# 20399       Westwood        2772       2770 2018-10-02           2   HS
# 30684       Westwood        2772       2770 2018-10-02           2   HS
# 40969       Westwood        2772       2770 2018-10-02           2   HS
# 51254       Westwood        2772       2770 2018-10-02           2   HS
# 61539       Westwood        2772       2770 2018-10-02           2   HS
# 10170       Westwood        2772       2770 2018-10-09           2   HS
# 20455       Westwood        2772       2770 2018-10-09           2   HS
# 30740       Westwood        2772       2770 2018-10-09           2   HS
# 41025       Westwood        2772       2770 2018-10-09           2   HS
# 51310       Westwood        2772       2770 2018-10-09           2   HS
# 61595       Westwood        2772       2770 2018-10-09           2   HS
# 10226       Westwood        2767       2770 2018-10-16          -3   HS
# 20511       Westwood        2767       2770 2018-10-16          -3   HS
# 30796       Westwood        2767       2770 2018-10-16          -3   HS
# 41081       Westwood        2767       2770 2018-10-16          -3   HS
# 51366       Westwood        2767       2770 2018-10-16          -3   HS
# 61651       Westwood        2767       2770 2018-10-16          -3   HS
# 10282       Westwood        2760       2770 2018-10-23         -10   HS
# 20567       Westwood        2760       2770 2018-10-23         -10   HS
# 30852       Westwood        2760       2770 2018-10-23         -10   HS
# 41137       Westwood        2760       2770 2018-10-23         -10   HS
# 51422       Westwood        2760       2770 2018-10-23         -10   HS
# 61707       Westwood        2760       2770 2018-10-23         -10   HS
#
# [61710 rows x 6 columns]

# %%
plt.figure(figsize=(30, 30))
for school in set(combined['Campus']):
    plt.plot(combined[combined['Campus']==school]['Date'], combined[combined['Campus']==school]['Cumulative'], label = school)
#plt.plot(store['Order Date'], store['office_sales'], 'r-', label = 'office supplies')
#plt.xlabel('Date'); plt.ylabel('Sales'); plt.title('Sales of Furniture and Office Supplies')
plt.legend();

# %%
com
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-60ff787b3d2f> in <module>
# ----> 1 com
#
# NameError: name 'com' is not defined

# %%
from fbprophet import Prophet
com = combined.rename(columns={'Date': 'ds', 'Cumulative': 'y'})
com = com[com['Campus']=='Westwood']
com_model = Prophet(interval_width=0.95)
com_model.fit(com)

com_forecast = com_model.make_future_dataframe(periods=36, freq='M')
com_forecast = com_model.predict(com_forecast)

plt.figure(figsize=(18, 6))
com_model.plot(com_forecast, xlabel = 'Date', ylabel = 'stu')
plt.title('yo');
# Out:
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# /anaconda3/lib/python3.6/site-packages/pystan/misc.py:399: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(np.asarray(v).dtype, float):

# %%
com_forecast
# Out:
#             ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0   2012-09-11  2504.473515  2574.274399  2594.723471  2504.473515
# 1   2012-10-02  2506.087062  2578.195980  2598.510543  2506.087062
# 2   2012-10-16  2507.162760  2576.279844  2596.589323  2507.162760
# 3   2012-10-23  2507.700609  2576.647617  2596.678278  2507.700609
# 4   2012-10-30  2508.238458  2574.709902  2596.149105  2508.238458
# 5   2012-11-06  2508.776307  2573.299649  2593.233998  2508.776307
# 6   2012-11-13  2509.314156  2572.608783  2592.892504  2509.314156
# 207    126.863393                   0.0                         0.0
# 208    106.146274                   0.0                         0.0
# 209    102.258801                   0.0                         0.0
# 210     94.400530                   0.0                         0.0
# 211     79.100481                   0.0                         0.0
# 212     65.788229                   0.0                         0.0
# 213   -583.321976                   0.0                         0.0
# 214   -505.677476                   0.0                         0.0
# 215    140.212880                   0.0                         0.0
# 216    139.169665                   0.0                         0.0
# 217    133.292556                   0.0                         0.0
# 218    123.794145                   0.0                         0.0
# 219    126.801439                   0.0                         0.0
# 220    105.991277                   0.0                         0.0
# 221    102.308616                   0.0                         0.0
# 222     94.482425                   0.0                         0.0
# 223     79.194995                   0.0                         0.0
# 224     66.290752                   0.0                         0.0
# 225   -573.604509                   0.0                         0.0
# 226   -516.326522                   0.0                         0.0
# 227    140.202413                   0.0                         0.0
# 228    139.240167                   0.0                         0.0
#
#      multiplicative_terms_upper         yhat
# 0                           0.0  2584.832333
# 1                           0.0  2588.280543
# 2                           0.0  2586.545991
# 3                           0.0  2586.665693
# 4                           0.0  2585.523485
# 5                           0.0  2583.461079
# 6                           0.0  2581.825041
# 7                           0.0  2579.005613
# 8                           0.0  2576.870021
# 9                           0.0  2576.239061
# 10                          0.0  2578.531738
# 11                          0.0  2580.050800
# 12                          0.0  2573.790947
# 13                          0.0  2568.209456
# 14                          0.0  2565.441871
# 15                          0.0  2565.034555
# 16                          0.0  2564.717201
# 17                          0.0  2564.052273
# 18                          0.0  2555.541782
# 19                          0.0  2548.413779
# 20                          0.0  2611.781474
# 21                          0.0  2605.852528
# 22                          0.0  2599.922193
# 23                          0.0  2595.640614
# 24                          0.0  2595.851441
# 25                          0.0  2594.743715
# 26                          0.0  2593.640818
# 27                          0.0  2592.351093
# 28                          0.0  2589.139321
# 29                          0.0  2587.424582
# ..                          ...          ...
# 199                         0.0  2719.684990
# 200                         0.0  2804.271651
# 201                         0.0  2184.475816
# 202                         0.0  2106.596934
# 203                         0.0  2881.784945
# 204                         0.0  2882.538158
# 205                         0.0  2797.405736
# 206                         0.0  2870.304267
# 207                         0.0  2779.404722
# 208                         0.0  2855.456209
# 209                         0.0  2853.017895
# 210                         0.0  2751.489241
# 211                         0.0  2752.045779
# 212                         0.0  2821.144681
# 213                         0.0  2078.314116
# 214                         0.0  2252.727221
# 215                         0.0  2900.166683
# 216                         0.0  2804.655126
# 217                         0.0  2896.294599
# 218                         0.0  2888.295329
# 219                         0.0  2811.989686
# 220                         0.0  2873.590678
# 221                         0.0  2871.307210
# 222                         0.0  2769.062648
# 223                         0.0  2851.241836
# 224                         0.0  2839.886699
# 225                         0.0  2105.523096
# 226                         0.0  2260.317665
# 227                         0.0  2823.176216
# 228                         0.0  2838.070557
#
# [229 rows x 19 columns]

# %%
import great_expectations as ge

# %%
dd = great_expectations

# %%
dd.data_context()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-873496ac05c8> in <module>
# ----> 1 dd.data_context()
#
# TypeError: 'module' object is not callable

# %%
import pandas as pd

# %%
df = ge.read_csv('./test.csv')

# %%
df.Type.value_counts()
# Out:
# ES       6449
# MS       1975
# HS       1203
# Other     658
# Name: Type, dtype: int64
